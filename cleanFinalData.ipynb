# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read schools datasets
schools = gpd.read_parquet("data/brazil_schools_census_education_metrics.parquet")

# %%
schools["education_level"].unique()
# Out:
# array(['Ensino Fundamental', 'Educação Infantil',
#        'Educação Infantil, Ensino Fundamental, Ensino Médio',
#        'Educação Infantil, Ensino Fundamental',
#        'Ensino Fundamental, Ensino Médio', '',
#        'Ensino Fundamental, Educação de Jovens Adultos',
#        'Ensino Fundamental, Ensino Médio, Educação de Jovens Adultos',
#        'Ensino Médio',
#        'Educação Infantil, Ensino Fundamental, Ensino Médio, Educação Profissional',
#        'Educação de Jovens Adultos',
#        'Educação Infantil, Ensino Fundamental, Educação de Jovens Adultos',
#        'Ensino Médio, Educação Profissional',
#        'Educação Infantil, Ensino Fundamental, Ensino Médio, Educação de Jovens Adultos',
#        'Ensino Fundamental, Ensino Médio, Educação Profissional',
#        'Ensino Médio, Educação de Jovens Adultos',
#        'Educação Profissional',
#        'Educação Infantil, Educação de Jovens Adultos',
# ...

# %%
schools_edinf = schools["education_level"].str.contains("Educação Infantil")

# %%
# Out:
# Index(['abbrev_state', 'name_muni', 'code_school', 'name_school',
#        'education_level', 'education_level_others', 'admin_category',
#        'address', 'phone_number', 'government_level', 'private_school_type',
#        'private_government_partnership', 'regulated_education_council',
#        'service_restriction', 'size', 'urban', 'location_type', 'date_update',
#        'geometry', 'NO_ENTIDADE', 'CO_ENTIDADE_x', 'TP_DEPENDENCIA',
#        'TP_CATEGORIA_ESCOLA_PRIVADA', 'TP_LOCALIZACAO',
#        'TP_LOCALIZACAO_DIFERENCIADA', 'QT_SALAS_UTILIZADAS_DENTRO',
#        'QT_SALAS_UTILIZADAS_FORA', 'QT_SALAS_UTILIZADAS', 'QT_MAT_BAS',
#        'QT_MAT_INF', 'QT_MAT_INF_CRE', 'QT_MAT_INF_PRE', 'QT_MAT_FUND',
#        'QT_MAT_FUND_AI', 'QT_MAT_FUND_AF', 'QT_MAT_MED', 'QT_MAT_PROF',
#        'QT_MAT_PROF_TEC', 'QT_MAT_EJA', 'QT_MAT_EJA_FUND', 'QT_MAT_EJA_MED',
#        'QT_MAT_ESP', 'QT_MAT_ESP_CC', 'QT_MAT_ESP_CE', 'QT_MAT_BAS_0_3',
# ...

# %%
schools.columns[100:]
# Out:
# Index(['FUN_CAT_2', 'FUN_CAT_3', 'FUN_CAT_4', 'FUN_CAT_5', 'FUN_CAT_6',
#        'FUN_AI_CAT_1', 'FUN_AI_CAT_2', 'FUN_AI_CAT_3', 'FUN_AI_CAT_4',
#        'FUN_AI_CAT_5', 'FUN_AI_CAT_6', 'FUN_AF_CAT_1', 'FUN_AF_CAT_2',
#        'FUN_AF_CAT_3', 'FUN_AF_CAT_4', 'FUN_AF_CAT_5', 'FUN_AF_CAT_6',
#        'MED_CAT_1', 'MED_CAT_2', 'MED_CAT_3', 'MED_CAT_4', 'MED_CAT_5',
#        'MED_CAT_6', 'CO_ENTIDADE', 'ED_INF_CAT_0', 'CRE_CAT_0', 'PRE_CAT_0',
#        'FUN_CAT_0', 'FUN_AI_CAT_0', 'FUN_AF_CAT_0', 'FUN_01_CAT_0',
#        'FUN_02_CAT_0', 'FUN_03_CAT_0', 'FUN_04_CAT_0', 'FUN_05_CAT_0',
#        'FUN_06_CAT_0', 'FUN_07_CAT_0', 'FUN_08_CAT_0', 'FUN_09_CAT_0',
#        'MULT_ETA_CAT_0', 'MED_CAT_0', 'MED_01_CAT_0', 'MED_02_CAT_0',
#        'MED_03_CAT_0', 'MED_04_CAT_0', 'MED_NS_CAT_0', 'lat', 'lon'],
#       dtype='object')

# %%
gdf = gpd.read_parquet("outputs/23112023_para_hexs_final.parquet")

# %%
gdf.columns.tolist()
# Out:
# ['hex',
#  'geometry',
#  'population_2020',
#  'pop_3_5_years_adj',
#  'pop_6_14_years_adj',
#  'pop_15_17_years_adj',
#  'pop_18_years_adj',
#  'V002_adj',
#  'V003_adj',
#  'income_pc',
#  'ensino_fundamental',
#  'educacao_infantil',
#  'ensino_medio',
#  'educacao_jovens_adultos',
#  'educacao_profissional',
#  'no_specified',
#  'publica',
#  'federal',
#  'estadual',
#  'municipal',
#  'privada',
#  'code_school',
#  'QT_SALAS_UTILIZADAS_DENTRO',
#  'QT_SALAS_UTILIZADAS_FORA',
#  'QT_SALAS_UTILIZADAS',
#  'QT_MAT_BAS',
#  'QT_MAT_INF',
#  'QT_MAT_INF_CRE',
#  'QT_MAT_INF_PRE',
#  'QT_MAT_FUND',
#  'QT_MAT_FUND_AI',
#  'QT_MAT_FUND_AF',
#  'QT_MAT_MED',
#  'QT_MAT_PROF',
#  'QT_MAT_PROF_TEC',
#  'QT_MAT_EJA',
#  'QT_MAT_EJA_FUND',
#  'QT_MAT_EJA_MED',
#  'QT_MAT_ESP',
#  'QT_MAT_ESP_CC',
#  'QT_MAT_ESP_CE',
#  'QT_MAT_BAS_0_3',
#  'QT_MAT_BAS_4_5',
#  'QT_MAT_BAS_6_10',
#  'QT_MAT_BAS_11_14',
#  'QT_MAT_BAS_15_17',
#  'QT_MAT_BAS_18_MAIS',
#  'QT_DOC_BAS',
#  'QT_DOC_INF',
# ...

# %%
gdf.columns[:22]
# Out:
# Index(['hex', 'geometry', 'population_2020', 'pop_3_5_years_adj',
#        'pop_6_14_years_adj', 'pop_15_17_years_adj', 'pop_18_years_adj',
#        'V002_adj', 'V003_adj', 'income_pc', 'ensino_fundamental',
#        'educacao_infantil', 'ensino_medio', 'educacao_jovens_adultos',
#        'educacao_profissional', 'no_specified', 'publica', 'federal',
#        'estadual', 'municipal', 'privada', 'code_school'],
#       dtype='object')

# %%
gdf.columns[22:-1][gdf.columns[22:-1].str.contains("INF")]
# Out:
# Index(['QT_MAT_INF', 'QT_MAT_INF_CRE', 'QT_MAT_INF_PRE', 'QT_DOC_INF',
#        'QT_DOC_INF_CRE', 'QT_DOC_INF_PRE', 'QT_TUR_INF', 'QT_TUR_INF_CRE',
#        'QT_TUR_INF_PRE', 'ratio_MAT_DOC_INF', 'ratio_MAT_DOC_INF_CRE',
#        'ratio_MAT_DOC_INF_PRE', 'ED_INF_CAT_0', 'AVG_QT_MAT_INF',
#        'AVG_QT_MAT_INF_CRE', 'AVG_QT_MAT_INF_PRE', 'AVG_QT_DOC_INF',
#        'AVG_QT_DOC_INF_CRE', 'AVG_QT_DOC_INF_PRE', 'AVG_QT_TUR_INF',
#        'AVG_QT_TUR_INF_CRE', 'AVG_QT_TUR_INF_PRE'],
#       dtype='object')

# %%
("QT_MAT_INF",)

("QT_DOC_INF",)

("QT_TUR_INF",)

("ratio_MAT_DOC_INF",)

("ED_INF_CAT_0",)

("AVG_QT_MAT_INF",)

("AVG_QT_DOC_INF",)

("AVG_QT_TUR_INF",)

# %%
"pop_3_5_years_adj"

"income_pc"

"Travel time to the nearest school by foot"

# %%
column_names = {
    'hex' : 'hex_id',
    'geometry': 'geometry',
    'population_2020': 'pop_total_meta_2020',
    'pop_3_5_years_adj': 'pop_3_5_years_censo_2010',
    'pop_6_14_years_adj': 'pop_6_14_years_censo_2010',
    'pop_15_17_years_adj': 'pop_15_17_years_censo_2010',
    'pop_18_years_adj': 'pop_18_years_censo_2010',
    'V002_adj': 'pop_total_censo_censo_2010',
    'V003_adj': 'total_households_censo_2020',
    'income_pc': 'income_per_capita_censo_2020',
    'educacao_infantil': 'n_schools_educacao_infantil',
    'ensino_fundamental': 'n_schools_ensino_fundamental',
    'ensino_medio': 'n_schools_ensino_medio',
    'educacao_jovens_adultos': 'n_schools_educacao_jovens_adultos',
    'educacao_profissional': 'n_schools_educacao_profissional',
    'no_specified': 'n_schools_no_specified', # VERIFY
    'publica': 'n_schools_publica',
    'federal': 'n_schools_federal',
    'estadual': 'n_schools_estadual',
    'municipal': 'n_schools_municipal',
    'privada': 'n_schools_privada',
    'QT_SALAS_UTILIZADAS_DENTRO': 'n_classrooms_used_inside',
    'QT_SALAS_UTILIZADAS_FORA': 'n_classrooms_used_outside',
    'QT_SALAS_UTILIZADAS': 'n_classrooms_used_total',
    'QT_MAT_BAS': 'n_students_basico',
    'QT_MAT_INF': 'n_students_educacao_infantil',
    'QT_MAT_INF_CRE': 'n_students_educacao_infantil_creche',
    'QT_MAT_INF_PRE': 'n_students_educacao_infantil_preescola',
    'QT_MAT_FUND': 'n_students_ensino_fundamental',
    'QT_MAT_FUND_AI': 'n_students_ensino_fundamental_anos_iniciais',
    'QT_MAT_FUND_AF': 'n_students_ensino_fundamental_anos_finais',
    'QT_MAT_MED': 'n_students_ensino_medio',
    'QT_MAT_PROF': 'n_students_educacao_profissional',
    'QT_MAT_PROF_TEC': 'n_students_educacao_profissional_tecnico',
    'QT_MAT_EJA': 'n_students_eja',
    'QT_MAT_EJA_FUND': 'n_students_eja_fund',
    'QT_MAT_EJA_MED': 'n_students_eja_med',
    'QT_MAT_ESP': 'n_students_especial',
    'QT_MAT_ESP_CC': 'n_students_especial_cc',
    'QT_MAT_ESP_CE': 'n_students_especial_ce',
    'QT_MAT_BAS_0_3': 'n_students_basico_0_3',
    'QT_MAT_BAS_4_5': 'n_students_basico_4_5',
    'QT_MAT_BAS_6_10': 'n_students_basico_6_10',
    'QT_MAT_BAS_11_14': 'n_students_basico_11_14',
    'QT_MAT_BAS_15_17': 'n_students_basico_15_17',
    'QT_MAT_BAS_18_MAIS': 'n_students_basico_18_mais',
    'QT_DOC_BAS': 'n_teachers_doc_bas',
    'QT_DOC_INF': 'n_teachers_doc_inf',
    'QT_DOC_INF_CRE': 'n_teachers_doc_inf_cre',
    'QT_DOC_INF_PRE': 'n_teachers_doc_inf_pre',
    'QT_DOC_FUND': 'n_teachers_doc_fund',
    'QT_DOC_FUND_AI': 'n_teachers_doc_fund_ai',
    'QT_DOC_FUND_AF': 'n_teachers_doc_fund_af',
    'QT_DOC_MED': 'n_teachers_doc_med',
    'QT_DOC_PROF': 'n_teachers_doc_prof',
    'QT_DOC_PROF_TEC': 'n_teachers_doc_prof_tec',
    'QT_DOC_EJA': 'n_teachers_doc_eja',
    'QT_DOC_EJA_FUND': 'n_teachers_doc_eja_fund',
    'QT_DOC_EJA_MED': 'n_teachers_doc_eja_med',

 'QT_SALAS_UTILIZADAS',
 'QT_MAT_BAS',
 'QT_MAT_INF',
 'QT_MAT_INF_CRE',
 'QT_MAT_INF_PRE',
 'QT_MAT_FUND',
 'QT_MAT_FUND_AI',
 'QT_MAT_FUND_AF',
 'QT_MAT_MED',
 'QT_MAT_PROF',
 'QT_MAT_PROF_TEC',
 'QT_MAT_EJA',
 'QT_MAT_EJA_FUND',
 'QT_MAT_EJA_MED',
 'QT_MAT_ESP',
 'QT_MAT_ESP_CC',
 'QT_MAT_ESP_CE',
 'QT_MAT_BAS_0_3',
 'QT_MAT_BAS_4_5',
 'QT_MAT_BAS_6_10',
 'QT_MAT_BAS_11_14',
 'QT_MAT_BAS_15_17',
 'QT_MAT_BAS_18_MAIS',
 'QT_DOC_BAS',
 'QT_DOC_INF',
 'QT_DOC_INF_CRE',
 'QT_DOC_INF_PRE',
 'QT_DOC_FUND',
 'QT_DOC_FUND_AI',
 'QT_DOC_FUND_AF',
 'QT_DOC_MED',
 'QT_DOC_PROF',
 'QT_DOC_PROF_TEC',
 'QT_DOC_EJA',
 'QT_DOC_EJA_FUND',
 'QT_DOC_EJA_MED',
 'QT_DOC_ESP',
 'QT_DOC_ESP_CC',
 'QT_DOC_ESP_CE',
 'QT_TUR_BAS',
 'QT_TUR_INF',
 'QT_TUR_INF_CRE',
 'QT_TUR_INF_PRE',
 'QT_TUR_FUND',
 'QT_TUR_FUND_AI',
 'QT_TUR_FUND_AF',
 'QT_TUR_MED',
 'QT_TUR_PROF',
 'QT_TUR_PROF_TEC',
 'QT_TUR_EJA',
 'QT_TUR_EJA_FUND',
 'QT_TUR_EJA_MED',
 'QT_TUR_ESP',
 'QT_TUR_ESP_CC',
 'QT_TUR_ESP_CE',
 'ratio_MAT_DOC_BAS',
 'ratio_MAT_DOC_INF',
 'ratio_MAT_DOC_INF_CRE',
 'ratio_MAT_DOC_INF_PRE',
 'ratio_MAT_DOC_FUND',
 'ratio_MAT_DOC_FUND_AI',
 'ratio_MAT_DOC_FUND_AF',
 'ratio_MAT_DOC_MED',
 'ratio_MAT_DOC_PROF',
 'ratio_MAT_DOC_PROF_TEC',
 'ratio_MAT_DOC_EJA',
 'ratio_MAT_DOC_EJA_FUND',
 'ratio_MAT_DOC_EJA_MED',
 'ratio_MAT_DOC_ESP',
 'ratio_MAT_DOC_ESP_CC',
 'ratio_MAT_DOC_ESP_CE',
 'ratio_MAT_SALAS',
 'FUN_CAT_1',
 'FUN_CAT_2',
 'FUN_CAT_3',
 'FUN_CAT_4',
 'FUN_CAT_5',
 'FUN_CAT_6',
 'FUN_AI_CAT_1',
 'FUN_AI_CAT_2',
 'FUN_AI_CAT_3',
 'FUN_AI_CAT_4',
 'FUN_AI_CAT_5',
 'FUN_AI_CAT_6',
 'FUN_AF_CAT_1',
 'FUN_AF_CAT_2',
 'FUN_AF_CAT_3',
 'FUN_AF_CAT_4',
 'FUN_AF_CAT_5',
 'FUN_AF_CAT_6',
 'ED_INF_CAT_0',
 'CRE_CAT_0',
 'PRE_CAT_0',
 'FUN_CAT_0',
 'FUN_AI_CAT_0',
 'FUN_AF_CAT_0',
 'FUN_01_CAT_0',
 'FUN_02_CAT_0',
 'FUN_03_CAT_0',
 'FUN_04_CAT_0',
 'FUN_05_CAT_0',
 'FUN_06_CAT_0',
 'FUN_07_CAT_0',
 'FUN_08_CAT_0',
 'FUN_09_CAT_0',
 'MULT_ETA_CAT_0',
 'MED_CAT_0',
 'MED_01_CAT_0',
 'MED_02_CAT_0',
 'MED_03_CAT_0',
 'MED_04_CAT_0',
 'MED_NS_CAT_0',
 'AVG_QT_SALAS_UTILIZADAS_DENTRO',
 'AVG_QT_SALAS_UTILIZADAS_FORA',
 'AVG_QT_SALAS_UTILIZADAS',
 'AVG_QT_MAT_BAS',
 'AVG_QT_MAT_INF',
 'AVG_QT_MAT_INF_CRE',
 'AVG_QT_MAT_INF_PRE',
 'AVG_QT_MAT_FUND',
 'AVG_QT_MAT_FUND_AI',
 'AVG_QT_MAT_FUND_AF',
 'AVG_QT_MAT_MED',
 'AVG_QT_MAT_PROF',
 'AVG_QT_MAT_PROF_TEC',
 'AVG_QT_MAT_EJA',
 'AVG_QT_MAT_EJA_FUND',
 'AVG_QT_MAT_EJA_MED',
 'AVG_QT_MAT_ESP',
 'AVG_QT_MAT_ESP_CC',
 'AVG_QT_MAT_ESP_CE',
 'AVG_QT_MAT_BAS_0_3',
 'AVG_QT_MAT_BAS_4_5',
 'AVG_QT_MAT_BAS_6_10',
 'AVG_QT_MAT_BAS_11_14',
 'AVG_QT_MAT_BAS_15_17',
 'AVG_QT_MAT_BAS_18_MAIS',
 'AVG_QT_DOC_BAS',
 'AVG_QT_DOC_INF',
 'AVG_QT_DOC_INF_CRE',
 'AVG_QT_DOC_INF_PRE',
 'AVG_QT_DOC_FUND',
 'AVG_QT_DOC_FUND_AI',
 'AVG_QT_DOC_FUND_AF',
 'AVG_QT_DOC_MED',
 'AVG_QT_DOC_PROF',
 'AVG_QT_DOC_PROF_TEC',
 'AVG_QT_DOC_EJA',
 'AVG_QT_DOC_EJA_FUND',
 'AVG_QT_DOC_EJA_MED',
 'AVG_QT_DOC_ESP',
 'AVG_QT_DOC_ESP_CC',
 'AVG_QT_DOC_ESP_CE',
 'AVG_QT_TUR_BAS',
 'AVG_QT_TUR_INF',
 'AVG_QT_TUR_INF_CRE',
 'AVG_QT_TUR_INF_PRE',
 'AVG_QT_TUR_FUND',
 'AVG_QT_TUR_FUND_AI',
 'AVG_QT_TUR_FUND_AF',
 'AVG_QT_TUR_MED',
 'AVG_QT_TUR_PROF',
 'AVG_QT_TUR_PROF_TEC',
 'AVG_QT_TUR_EJA',
 'AVG_QT_TUR_EJA_FUND',
 'AVG_QT_TUR_EJA_MED',
 'AVG_QT_TUR_ESP',
 'AVG_QT_TUR_ESP_CC',
 'AVG_QT_TUR_ESP_CE',
 'urban_area'
}
